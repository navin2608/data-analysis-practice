# %%
import pandas as pd
df=pd.read_csv("Z:\oct.csv")
df.head()
# Out:
#    material 1  material 2  material 3  condition  rating
# 0       55.33        1.72          54    1.66219   92.19
# 1       59.13        1.20          53    1.58399   92.74
# 2       57.39        1.42          55    1.61731   91.88
# 3       56.43        1.78          55    1.66228   92.80
# 4       55.98        1.58          54    1.63195   92.56

# %%
import matplotlib.pyplot as plt
plt.scatter(df["material 1"],df["rating"])

# %%
plt.scatter(df["material 2"],df["rating"])

# %%
plt.scatter(df["material 3"],df["rating"])

# %%
plt.scatter(df["condition"],df["rating"])

# %%
x=df[["material 1","material 2","material 3","condition"]]
y=df[["rating"]]

# %%
x,y
# Out:
# (    material 1  material 2  material 3  condition
#  0        55.33        1.72          54    1.66219
#  1        59.13        1.20          53    1.58399
#  2        57.39        1.42          55    1.61731
#  3        56.43        1.78          55    1.66228
#  4        55.98        1.58          54    1.63195
#  5        56.16        2.12          56    1.68034
#  6        54.85        1.17          54    1.58206
#  7        52.83        1.50          58    1.54998
#  8        54.52        0.87          57    1.56230
#  9        54.12        0.88          57    1.57818
#  10       51.72        0.00          56    1.60401
#  11       51.29        0.00          58    1.59594
#  12       53.22        1.31          58    1.54814
#  13       54.76        1.67          58    1.63134
#  14       53.34        1.81          59    1.60228
#  15       54.84        2.87          60    1.54949
#  16       54.03        1.19          60    1.57841
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
xtrain
# Out:
#     material 1  material 2  material 3  condition
# 66       69.73        0.06          54    1.28802
# 42       72.30        4.02          55    1.66783
# 55       64.05        1.64          57    1.33945
# 16       54.03        1.19          60    1.57841
# 39       73.74        0.00          54    1.73496
# 61       72.03        1.28          56    1.60390
# 79       63.13        1.60          52    1.66118
# 7        52.83        1.50          58    1.54998
# 81       62.25        3.56          50    1.49734
# 54       64.71        0.61          55    1.38934
# 19       57.88        1.28          62    1.56443
# 67       69.93        0.05          55    1.36399
# 25       58.30        3.11          62    1.29994
# 44       66.61        2.31          52    1.77967
# 13       54.76        1.67          58    1.63134
# 58       71.11        3.56          60    1.41229
# 3        56.43        1.78          55    1.66228
# 17       51.44        0.42          59    1.61183
# ...

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
xtest
# Out:
#     material 1  material 2  material 3  condition
# 30       62.82        0.88          59    1.40483
# 0        55.33        1.72          54    1.66219
# 22       61.42        1.49          62    1.41330
# 31       62.57        0.42          60    1.45056
# 18       53.54        1.39          59    1.51081
# 28       59.79        1.48          62    1.30621
# 10       51.72        0.00          56    1.60401
# 53       65.09        1.01          57    1.45939
# 4        55.98        1.58          54    1.63195
# 12       53.22        1.31          58    1.54814
# 49       62.34        0.00          48    2.00677
# 33       65.08        0.10          60    1.68940
# 68       70.60        0.00          55    1.42210
# 35       65.64        0.05          60    1.74919
# 69       75.54        0.00          55    1.67219
# 45       63.66        2.99          52    1.81271
# 75        5.53        7.99          40    1.99418
# 62       69.90        2.19          56    1.67265
# ...

# %%
reg.predict(xtest)
# Out:
# array([[91.21819659],
#        [92.42949694],
#        [91.20122531],
#        [91.36355786],
#        [92.2064664 ],
#        [91.14314362],
#        [92.81865119],
#        [91.15383   ],
#        [92.32956938],
#        [92.3460511 ],
#        [92.84801892],
#        [91.64109942],
#        [90.76420972],
#        [91.71286818],
#        [90.79922684],
#        [91.84753632],
#        [97.18627555],
#        [91.00083128],
#        [90.86459362],
#        [91.1551495 ],
#        [92.40588306],
#        [91.55942615],
#        [92.28208035],
#        [91.7151939 ],
#        [91.74108725]])

# %%
reg.score(xtest,ytest)
# Out:
# 0.9430738705939583
